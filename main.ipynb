# %%
import pandas as pd

# %%
df=pd.read_csv("Data/query_de&co_11_06.csv")
len(df.columns)
# Out:
# 25

# %%
df[["order_id","order_id.1"]]
# Out:
#                                order_id                        order_id.1
# 0      00010242fe8c5a6d1ba2dd792cb16214  00010242fe8c5a6d1ba2dd792cb16214
# 1      00018f77f2f0320c557190d7a144bdd3  00018f77f2f0320c557190d7a144bdd3
# 2      000229ec398224ef6ca0657da4fc703e  000229ec398224ef6ca0657da4fc703e
# 3      00042b26cf59d7ce69dfabb4e55b4fd9  00042b26cf59d7ce69dfabb4e55b4fd9
# 4      00048cc3ae777c65dbb7d2a0634bc1ea  00048cc3ae777c65dbb7d2a0634bc1ea
# ...                                 ...                               ...
# 78110  fffb9224b6fc7c43ebb0904318b10b5f  fffb9224b6fc7c43ebb0904318b10b5f
# 78111  fffb9224b6fc7c43ebb0904318b10b5f  fffb9224b6fc7c43ebb0904318b10b5f
# 78112  fffb9224b6fc7c43ebb0904318b10b5f  fffb9224b6fc7c43ebb0904318b10b5f
# 78113  fffce4705a9662cd70adb13d4a31832d  fffce4705a9662cd70adb13d4a31832d
# 78114  fffe18544ffabc95dfada21779c9644f  fffe18544ffabc95dfada21779c9644f
#
# [78115 rows x 2 columns]

# %%
a=df["order_id"]==df["order_id.1"]
if False in a:
    print("há falsos")
else:
    print("Não há falsos")
# Out:
# Não há falsos

# %% [markdown]
# As colunas order_id e order_id.1 são iguais

# %%
a=df["product_id"]==df["product_id.1"]
if False in a:
    print("há falsos")
else:
    print("Não há falsos")
# Out:
# Não há falsos

# %% [markdown]
# O mesmo para as colunas product_id

# %%
df.drop(columns=["order_id.1","product_id.1"],inplace=True)

len(df.columns)
# Out:
# 23

# %%
display(df)
# Out:
#                                order_id  order_item_id  \
# 0      00010242fe8c5a6d1ba2dd792cb16214              1
# 1      00018f77f2f0320c557190d7a144bdd3              1
# 2      000229ec398224ef6ca0657da4fc703e              1
# 3      00042b26cf59d7ce69dfabb4e55b4fd9              1
# 4      00048cc3ae777c65dbb7d2a0634bc1ea              1
# ...                                 ...            ...
# 78110  fffb9224b6fc7c43ebb0904318b10b5f              2
# 78111  fffb9224b6fc7c43ebb0904318b10b5f              3
# 78112  fffb9224b6fc7c43ebb0904318b10b5f              4
# 78113  fffce4705a9662cd70adb13d4a31832d              1
# 78114  fffe18544ffabc95dfada21779c9644f              1
#
#                              product_id                         seller_id  \
# 0      4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1      e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2      c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# ...

# %%
df.drop_duplicates(inplace=True)
len(df)
# Out:
# 78115
