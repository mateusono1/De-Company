# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import os

# %%
pd.set_option('display.max_columns', None)
df=pd.read_csv("../Data/Dataframelimpa_sem_latlong.csv")

df["product_category_name"]=pd.Categorical(df["product_category_name"])
df["seller_zip_code_prefix"]=pd.Categorical(df["seller_zip_code_prefix"])
df["customer_zip_code_prefix"]=pd.Categorical(df["customer_zip_code_prefix"])
df["payment_type"]=pd.Categorical(df["payment_type"])

df["product_category_name"]=df["product_category_name"].cat.codes
df["seller_zip_code_prefix"]=df["seller_zip_code_prefix"].cat.codes
df["customer_zip_code_prefix"]=df["customer_zip_code_prefix"].cat.codes
df["payment_type"]=df["payment_type"].cat.codes

df=df[["product_category_name","delivery_time","product_weight_g","product_length_cm","product_height_cm","product_width_cm",
       "seller_zip_code_prefix","payment_type","customer_zip_code_prefix","price","freight_value"]]


df.dropna(subset=["product_category_name"],inplace=True)

display(df)
# Out:
#        product_category_name  delivery_time  product_weight_g  \
# 0                         18           7.61             650.0
# 1                         31           7.95            3050.0
# 2                         40           6.67             450.0
# 3                         39           8.42             200.0
# 4                          8           9.98            2000.0
# ...                      ...            ...               ...
# 64873                     25          20.91             175.0
# 64874                     31           4.72             750.0
# 64875                     21          21.08            2700.0
# 64876                     21           4.80             967.0
# 64877                     25           1.96             100.0
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 0                   28.0                9.0              14.0
# 1                   33.0               13.0              33.0
# 2                   24.0                8.0              15.0
# 3                   27.0                5.0              20.0
# 4                   30.0               12.0              16.0
# ...                  ...                ...               ...
# 64873               20.0               20.0              20.0
# 64874               30.0               30.0              11.0
# 64875               60.0               15.0              15.0
# 64876               21.0               24.0              19.0
# 64877               20.0               20.0              20.0
#
#        seller_zip_code_prefix  payment_type  customer_zip_code_prefix   price  \
# 0                        1022             1                      5985   58.90
# 1                        1152             1                      6824  199.00
# 2                         773             0                      7223   21.90
# 3                           2             1                      4592   19.90
# 4                         218             1                      3467  145.95
# ...                       ...           ...                       ...     ...
# 64873                     624             1                      8579  180.00
# 64874                     235             1                      1372   89.90
# 64875                     348             1                      8782  229.90
# 64876                    1292             1                      1312   99.90
# 64877                     313             1                      3987   55.99
#
#        freight_value
# 0              13.29
# 1              17.87
# 2              12.69
# 3              11.85
# 4              11.65
# ...              ...
# 64873          48.14
# 64874          11.83
# 64875          44.02
# 64876          16.95
# 64877           8.72
#
# [64878 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# product_category_name       0
# delivery_time               0
# product_weight_g            0
# product_length_cm           0
# product_height_cm           0
# product_width_cm            0
# seller_zip_code_prefix      0
# payment_type                0
# customer_zip_code_prefix    0
# price                       0
# freight_value               0
# dtype: int64

# %% [markdown]
# ## Treinando o modelo

# %%
x=df.drop(columns=["delivery_time"])
y=df["delivery_time"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 25.437573568124172
