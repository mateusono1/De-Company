# %%
import pandas as pd

# %% [markdown]
# # Importando as bases

# %% [markdown]
# fiz outra query (deu 117k linhas) e não dropei nada, para não perder informação de ID. Meu objetivo é tentar traçar alguma relação entre o Kaggle e o AWS

# %%
kaggle=pd.read_csv("../Data/csv_Kaggle.csv")

# %%
query=pd.read_csv("../Data/query_27_06.csv")

# %%
display(kaggle)
# Out:
#                                order_id                       customer_id  \
# 0      cee3292f46ede6ea1dfabfcb200fcf47  0f8feee05f830b2be5955cf674a7d8f1
# 1      50dca53ca33b739bef09e7933e8b380e  d0580aed7f303a707d93b00b84c591a7
# 2      8087ec71e393d4dc6fc48041fe63cd51  b8dfb418e6cad762b91febf827d4b2e5
# 3      e6b6557ce111de79b31cc857f20ba212  90c8fe0d707ea62be3fcb5abd7bc784f
# 4      0b09c5e4c2512f627190ac55a78c35a3  6ba83000cf8c24413916a7a72fcb5173
# ...                                 ...                               ...
# 28147  81cedc4d2132eb6f512354166e51b187  a8f6bb35d78515a1762eb626d52b6352
# 28148  95811675a89b66659996da5285a021db  5885969ba920706beb8d5381a2ba981c
# 28149  25bd2ad9d282f59e4e6a048ef9bf214f  be34bf56044c5614fc66d97251c0adc6
# 28150  9f9ac312604229686c04260955495c70  3357c4c3ecf82709236158cb2ac0ce9b
# 28151  f51c9940410ef77422e4efbca407c161  ceeaae7ee13b40a086d0140281bef2ac
#
#       order_purchase_timestamp order_approved_at
# ...

# %%
display(query)
# Out:
#                                 order_id                       customer_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1       00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2       000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3                                    NaN                               NaN
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
# ...                                  ...                               ...
# 117599                               NaN                               NaN
# 117600                               NaN                               NaN
# 117601  fffce4705a9662cd70adb13d4a31832d  29309aa813182aaddc9b259e31b870e6
# 117602  fffe18544ffabc95dfada21779c9644f  b5e6afd5a41800fdf401e0272ca74655
# 117603                               NaN                               NaN
#
# ...

# %%
k_order_id=list(kaggle["order_id"])
q_order_id=list(query["order_id"])

k_customer_id=list(kaggle["customer_id"])
q_customer_id=list(query["customer_id"])

valores_comum=set(q_order_id) & set(k_order_id)
valores_comum_2=set(q_customer_id) & set(k_customer_id)

print(valores_comum,valores_comum_2)
# Out:
# set() set()
